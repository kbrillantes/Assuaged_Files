# %%
import pandas as pd
import numpy as np
import nltk
import re
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import silhouette_samples, silhouette_score
import seaborn as sns

# %%
df=pd.read_csv('mgb_aud_tweets_july2020.csv')
df.head()
# Out:
#                         Time                   Id  \
# 0  2020-07-29 20:10:45+00:00  1288466505592647680
# 1  2020-07-28 18:32:24+00:00  1138260140245696512
# 2  2020-07-29 21:08:14+00:00   890886953037647872
# 3  2020-07-26 00:16:37+00:00  1071352236083736578
# 4  2020-07-28 18:28:59+00:00             17622490
#
#                                               Tweets
# 0                 Jesus. Justice for Israel Jackson.
# 1  As of last weekend I finished a month internsh...
# 2                                All about *papistan
# 3                      : Purell? Never heard of her.
# 4                                                NaN

# %%
nltk.download('wordnet')   
# define stop words
nltk.download('stopwords') 
stop_words = set(stopwords.words("english"))

def fix_Text2(text):
    letters_only = re.sub("[^a-zA-Z]"," ", str(text))
    words=letters_only.lower().split()
    meaningful=[WordNetLemmatizer().lemmatize(word) for word in words if word not in stop_words]
    return(" ".join(meaningful))

num_resp = df["Tweets"].size   #df
clean_description_lemmization = []     #clean_

for i in range(0,num_resp):
    clean_description_lemmization.append(fix_Text2(df["Tweets"][i])) #clean_

clean_description_lemmization[0:5]    ## clean_
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Lenovo
# [nltk_data]     U31\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Lenovo
# [nltk_data]     U31\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['jesus justice israel jackson',
#  'last weekend finished month internship ccof certified farm blast',
#  'papistan',
#  'purell never heard',
#  'nan']

# %%
len(clean_description_lemmization)
# Out:
# 687

# %%
# word cloud
text_wc = " ".join(item for item in clean_description_lemmization)    #clean_
wordcloud = WordCloud(background_color="white").generate(text_wc)

plt.figure(figsize = (10, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
tv=TfidfVectorizer() 
tv_transform=tv.fit_transform(clean_description_lemmization)
tv_transform.shape
# Out:
# (687, 2550)

# %% [markdown]
# ## determining best number of clusters

# %%
from sklearn.cluster import KMeans
scores = [KMeans(n_clusters=i+2).fit(tv_transform).inertia_ 
          for i in range(10)]
sns.lineplot(np.arange(2, 12), scores)
plt.xlabel('Number of clusters')
plt.ylabel("Inertia")
plt.title("Inertia of k-Means versus number of clusters")
# Out:
# Text(0.5, 1.0, 'Inertia of k-Means versus number of clusters')

# %%
#high dimension data
from sklearn import preprocessing
normalized_vectors = preprocessing.normalize(tv_transform)
scores = [KMeans(n_clusters=i+2).fit(normalized_vectors).inertia_  
          for i in range(10)]
sns.lineplot(np.arange(2, 12), scores)
plt.xlabel('Number of clusters')
plt.ylabel("Inertia")
plt.title("Inertia of Cosine k-Means versus number of clusters")
plt.savefig("intertia_cosine_kmeans.jpg", dpi=300)

# %% [markdown]
# ## audience clustering

# %%
from scipy.cluster.vq import kmeans,vq

# %%
num_clusters=8  # change the # of clusters
cluster_centers,distortion=kmeans(tv_transform.todense(),num_clusters)

# %% [markdown]
# ## unigram

# %%
tv=TfidfVectorizer(max_features=100, min_df=3)  # 1.change # of features 2.maybe min_df
tv_transform=tv.fit_transform(clean_description_lemmization)

# %%
terms=tv.get_feature_names()
for i in range(num_clusters):
    center_terms=dict(zip(terms,list(cluster_centers[i])))
    sorted_terms=sorted(center_terms,key=center_terms.get,reverse=True)
    print(sorted_terms[:4])
# Out:
# ['via', 'sure', 'th', 'year']
# ['always', 'amp', 'anyone', 'back']
# ['lot', 'always', 'amp', 'anyone']
# ['always', 'amp', 'anyone', 'back']
# ['dont', 'always', 'amp', 'anyone']
# ['via', 'anyone', 'happy', 'vitamin']
# ['easy', 'first', 'let', 'change']
# ['back', 'friend', 'good', 'today']

# %% [markdown]
# ## bigram

# %%
tv=TfidfVectorizer(max_features=100,ngram_range=(2,2)) 
tv_transform=tv.fit_transform(clean_description_lemmization)

# %%
terms=tv.get_feature_names()
for i in range(num_clusters):
    center_terms=dict(zip(terms,list(cluster_centers[i])))
    sorted_terms=sorted(center_terms,key=center_terms.get,reverse=True)
    print(sorted_terms[:4])
# Out:
# ['take care', 'seems like', 'self portrait', 'winning one']
# ['able tell', 'always joy', 'anyone josie', 'bad diet']
# ['made feel', 'able tell', 'always joy', 'anyone josie']
# ['able tell', 'always joy', 'anyone josie', 'bad diet']
# ['day ago', 'able tell', 'always joy', 'anyone josie']
# ['take care', 'anyone josie', 'heart attack', 'te gustan']
# ['de estar', 'exercise way', 'life dont', 'che belle']
# ['bad diet', 'five minute', 'gut heal', 'summer style']

# %% [markdown]
# ## unigram & bigram

# %%
tv=TfidfVectorizer(max_features=100,ngram_range=(1,2)) 
tv_transform=tv.fit_transform(clean_description_lemmization)

# %%
terms=tv.get_feature_names()
for i in range(num_clusters):
    center_terms=dict(zip(terms,list(cluster_centers[i])))
    sorted_terms=sorted(center_terms,key=center_terms.get,reverse=True)
    print(sorted_terms[:7])
# Out:
# ['use', 'summer', 'take', 'would', 'year', 'ever', 'lot']
# ['always', 'amp', 'anyone', 'back', 'beautiful', 'best', 'better']
# ['lot', 'always', 'amp', 'anyone', 'back', 'beautiful', 'best']
# ['always', 'amp', 'anyone', 'back', 'beautiful', 'best', 'better']
# ['dont', 'always', 'amp', 'anyone', 'back', 'beautiful', 'best']
# ['use', 'anyone', 'hard', 'video', 'better', 'goal', 'man']
# ['easy', 'find', 'let', 'change', 'retweet', 'dream', 'sign']
# ['back', 'free', 'got', 'today', 'say', 'always', 'amp']

# %% [markdown]
# ## inspect importance

# %%
columns=tv.get_feature_names() # feature names
#transform to DF
df_description=pd.DataFrame(tv_transform.toarray(),columns=columns) #df_
# insepct transformation
tv_sum=df_description.sum() #df
tv_sum.columns = ['importance']

# %%
tv_sum.sort_values(ascending=False).head(20)
# Out:
# nan       60.552758
# day       15.016196
# people    14.443634
# love      14.338865
# time      14.198141
# life      13.525328
# like      12.639644
# get       12.116725
# one       11.662714
# via       10.704655
# amp       10.469851
# need      10.314830
# new       10.184404
# see       10.051731
# go         9.916771
# know       9.654593
# never      9.642406
# best       9.534178
# de         9.355029
# think      9.251144
# dtype: float64

# %%
df_sum=pd.DataFrame(tv_sum,columns=['importance']).sort_values(by='importance',ascending=False).iloc[1:15]

# %%
sns.set()
fig,ax=plt.subplots()
ax.bar(df_sum.index,df_sum.importance,label='importance')
ax.set_xticklabels(df_sum.index,rotation=90)
plt.show()

# %% [markdown]
# ## feature importance by cluster

# %%
tv_transform.todense().shape
# Out:
# (687, 100)

# %%
clust1=pd.DataFrame(zip(terms,list(cluster_centers[1]))).sort_values(by=1,ascending=False)

# %%
clust1
# Out:
#          0    1
# 0   always  0.0
# 63     one  0.0
# 73    sign  0.0
# 72     see  0.0
# 71     say  0.0
# ..     ...  ...
# 30   great  0.0
# 29     got  0.0
# 28    good  0.0
# 27    goal  0.0
# 99   youre  0.0
#
# [100 rows x 2 columns]

# %%
clust1.iloc[:, 0]
# Out:
# 0     always
# 63       one
# 73      sign
# 72       see
# 71       say
#        ...
# 30     great
# 29       got
# 28      good
# 27      goal
# 99     youre
# Name: 0, Length: 100, dtype: object

# %%
from sklearn.metrics import silhouette_score

# %%
tv_sum.index
# Out:
# Index(['always', 'amp', 'anyone', 'back', 'beautiful', 'best', 'better', 'big',
#        'care', 'change', 'check', 'covid', 'day', 'de', 'dont', 'dream',
#        'easy', 'ever', 'exercise', 'fear', 'feel', 'feeling', 'find', 'first',
#        'free', 'get', 'go', 'goal', 'good', 'got', 'great', 'happy', 'hard',
#        'health', 'heart', 'help', 'im', 'important', 'know', 'la', 'last',
#        'let', 'life', 'like', 'look', 'lot', 'love', 'made', 'mail', 'make',
#        'man', 'may', 'mean', 'mind', 'minute', 'money', 'much', 'name', 'nan',
#        'need', 'never', 'new', 'nothing', 'one', 'online', 'pain', 'people',
#        'please', 'retweet', 'right', 'safe', 'say', 'see', 'sign', 'someone',
#        'sometimes', 'start', 'still', 'summer', 'sure', 'take', 'thank',
#        'thing', 'think', 'thought', 'time', 'today', 'use', 'via', 'video',
#        'vitamin', 'vote', 'want', 'way', 'week', 'word', 'work', 'would',
#        'year', 'youre'],
#       dtype='object')

# %%
#left = 

#In [43]: right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
   #....:                       'key2': ['K0', 'K0', 'K0', 'K0'],
   #....:                       'C': ['C0', 'C1', 'C2', 'C3'],
   #....:                       'D': ['D0', 'D1', 'D2', 'D3']})
   #....: 

#In [44]: result = pd.merge(left, right, on=['key1', 'key2'])

# %%
for col in clust1.columns: 
    print(col)
# Out:
# 0
# 1

# %%
for col in tv_sum.columns: 
    print(col)
# Out:
# importance

# %%
tv_sum
# Out:
# always        5.455646
# amp          10.469851
# anyone        4.866557
# back          5.556791
# beautiful     5.556171
#                ...
# word          5.935127
# work          6.886877
# would         4.574754
# year          8.141195
# youre         4.661621
# Length: 100, dtype: float64

# %%
for col in tv_sum.columns: 
    print(col)
# Out:
# importance

# %%
merged = pd.merge(clust1, tv_sum, right_index=True, left_on='0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-e84e6570b0e6> in <module>
# ----> 1 merged = pd.merge(clust1, tv_sum, right_index=True, left_on='0')
#
# E:\anaconda3v2\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# E:\anaconda3v2\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     570     ):
#     571         _left = _validate_operand(left)
# --> 572         _right = _validate_operand(right)
#     573         self.left = self.orig_left = _left
#     574         self.right = self.orig_right = _right
#
# E:\anaconda3v2\lib\site-packages\pandas\core\reshape\merge.py in _validate_operand(obj)
#    2000     elif isinstance(obj, ABCSeries):
#    2001         if obj.name is None:
# -> 2002             raise ValueError("Cannot merge a Series without a name")
#    2003         else:
#    2004             return obj.to_frame()
#
# ValueError: Cannot merge a Series without a name
